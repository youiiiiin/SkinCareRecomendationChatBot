# %%
# -*- coding: utf-8 -*-
import re

print ("Hello! My name is Vivi. I am from JY-II skin care company, a lot of people ask for my reccomendation of skin care. What's your name?")
name = input("My name is ")
print ("Oh! "+name+"! What a lovely name, I love it! From now on, I will be your personal skin care advisor, and I will ALWAYS be here for you. Now, tell me, which type of skin care products are you interested in?")
print ("a. mask")
print ("b. moisturizers")
print ("c. serums")
print ("d. cleansers")
print ("e. eye cares")


n = 1 

while (n == 1):
    text = input('\n>>> ')
    if re.search ("Mask|^a{1}$|\.", text, flags=re.IGNORECASE):
       print ("We have JY-II Facial Treatment Mask, It is for hydrated, radiant skin. Type 'one' to know more details or type 'others' for other products.")
       text = input('\n>>> ')
       if re.search ("one|1|more details", text, flags=re.IGNORECASE):
           print ("There are several benefits after using this mask.") 
           print ("1. brighter Glow - Improves radiance immediately after application by conditioning skin with intense hydration and boosting moisture retention.") 
           print ("2. Smoother Texture - Improves texture by plumping up skin with moisture for elevated smoothness, and it is reccomended for all skin types. So it's definitely suitable for you!")
           print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
           text = input('\n>>> ')
           while True:
               if re.search ("others|about us", text, flags=re.IGNORECASE):
                   break 
               else:
                   print ("I am not sure what are you talking about. Let's try again.")
                   print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
                   
       elif re.search ("others", text, flags=re.IGNORECASE):
           while True:
               if re.search ("others", text, flags=re.IGNORECASE):
                   break 
               else:
                   print ("I am not sure what are you talking about. Let's try again.")
                   print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
                   
              
    elif re.search ("moisturizers|^b{1}$|\.", text, flags=re.IGNORECASE):
        print ("Our R.N.A.POWER Radical New Age Cream can Supercharge your skin’s youthful radiance with our best-selling anti-aging cream.")
        print ("Packed with nourishing ingredients, this velvety moisturizing cream restores skin suppleness and elasticity1 with intense hydration.")
        if re.search ("two|2", text, flags=re.IGNORECASE):
            print ("After using this, you will get 1. Suppler Skin - Improves firmness from within by helping lock in moisture.")
            print ("Less Visible Wrinkles - Helps reduce the appearance of fine lines and wrinkles by plumping up the skin with moisture.")
            print ("Smoother Texture - Improves texture by smoothing the appearance of pores and surface roughness.")
            print ("Type others for other products. Type about us for introduction of our company!")
            text = input('\n>>> ')
            while True:
                if re.search ("others|about us", text, flags=re.IGNORECASE):
                    break
                else:
                    print ("I am not sure what are you talking about. Let's try again.")
                    print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
             
        elif re.search ("others", text, flags=re.IGNORECASE):
           while True:
               if re.search ("others", text, flags=re.IGNORECASE):
                   break 
               else:
                   print ("I am not sure what are you talking about. Let's try again.")
                   print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
                   
                   
        
    elif re.search ("serums|^c{1}$|\.", text, flags=re.IGNORECASE):
        print ("Here comes my favorite product, JY-II facial Treatment essence! Each bottle contains 90% PITERA, that bottle is sold every 2 second! Type three to know more details or type others for other products.")
        if re.search ("three|3", text, flags=re.IGNORECASE):
            print ("This serum does some magic...")
            print ("1. Brighter Glow - Improves radiance by diminishing cloudiness under the skin's surface caused by UV exposure.")
            print ("Prevents Spots - Helps prevent the formation of dark spots by inhibiting melanin production.")
            print ("Smoother Texture - Smooths the skin for a uniform surface that reflects light gently. You should waste no more time!")
            print ("Type others for other products. Type about us for introduction of our company!")
            text = input('\n>>> ')
            while True:
                if re.search ("others|about us", text, flags=re.IGNORECASE):
                    break
                else:
                    print ("I am not sure what are you talking about. Let's try again.")
                    print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
          
        elif re.search ("others", text, flags=re.IGNORECASE):
           while True:
               if re.search ("others", text, flags=re.IGNORECASE):
                   break 
               else:
                   print ("I am not sure what are you talking about. Let's try again.")
                   print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
                   
    elif re.search ("cleanser|^d{1}$|\.", text, flags=re.IGNORECASE):
        print ("We have JY-II Facial Treatment Cleanser. It is a foaming facial cleanser that gently removes impurities. Type four to know more deatails or type others for other products.")
        text = input('\n>>> ')
        if re.search ("four|4", text, flags=re.IGNORECASE):
            print ("Cleanser is extremely important! So this is definitely your right choice! These are the benefits of using it:")
            print ("Brighter Glow - Reveal radiance by removing impurities from skin for a clearer and brighter complexion.")
            print ("Smoother Texture - Improves texture by cleansing impurities from pores and conditioning the surface of your skin.")
            print ("Type others for other products. Type about us for introduction of our company!")
            text = input('\n>>> ')
            while True:
                if re.search ("others|about us", text, flags=re.IGNORECASE):
                    break
                else:
                    print ("I am not sure what are you talking about. Let's try again.")
                    print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
                   
        elif re.search ("others", text, flags=re.IGNORECASE):
           while True:
               if re.search ("others", text, flags=re.IGNORECASE):
                   break 
               else:
                   print ("I am not sure what are you talking about. Let's try again.")
                   print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
                   
    
    elif re.search ("eye cares|^e{1}$|\.", text, flags=re.IGNORECASE):
        print ("We have JY-II R.N.A.POWER Eye Cream. It is a nourishing eye cream that restores youthful smoothness. Type five to know more details or type others for other products.")
        text = input('\n>>> ')
        if re.search ("five|5", text, flags=re.IGNORECASE):
            print ("The eye is the window of the soul, buying this will be a good investment! not to mention how many adventages it brings...")
            print ("1. Suppler Skin - Improves firmness from within by locking in moisture.")
            print ("2. Less Visible Wrinkles - Reduces the appearance of wrinkles by plumping up the skin with moisture.")
            print ("3. Smoother Texture - Improves texture by smoothing the appearance of pores and surface roughness.")
            print ("Type others for other products. Type about JY-II for introduction of our company!")
            text = input('\n>>> ')
            while True:
                if re.search ("others|about us", text, flags=re.IGNORECASE):
                    break
                else:
                    print ("I am not sure what are you talking about. Let's try again.")
                    print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
           
        elif re.search ("others", text, flags=re.IGNORECASE):
           while True:
               if re.search ("others", text, flags=re.IGNORECASE):
                   break 
               else:
                   print ("I am not sure what are you talking about. Let's try again.")
                   print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
                        

    
    if re.search ("others", text, flags=re.IGNORECASE):
        print ("which type of skin care products are you interested in?")
        print ("a. mask")
        print ("b. moisturizers")
        print ("c. serums")
        print ("d. cleansers")
        print ("e. eye cares")
        print ()
        print ("Or would you like to know more about our company?")
        print ("Type 'About us' to get more information!")
        while True:
            text = input('\n>>> ')
            if re.search ("about us|a|b|c|d|e|.|mask|moisturizers|serums|cleaners|eyes cares", text, flags=re.IGNORECASE):
                break
    else:
        print ("I am not sure what are you talking about. Let's try again.")
        print ("Type 'others' for other products. Type 'about us' for introduction of our company!")
                   
        
        
    if re.search ("about us", text, flags=re.IGNORECASE):
        print ("OH MY GOD! "+name+", I am so happy that you asked about our company. Since I started to work in our company, I have gotten more and more friends!")
        print ("Our company is found in the USA, by two girls called Jill and Yaya, they found this company after they retired. The mission of our company is enriching people's life and their family around the world!")
        print ("Would you like to join us? Only 30USD you can start your JY-II business!")
        print ("Type 'call me' to contact a beauty consultant and start your business right away!")
        print ("Type 'skip' if you want to skip this WONDERFUL WONDERFUL WONDERFUL chance :(.")
        text = input('\n>>> ')
        if re.search ("call me", text, flags=re.IGNORECASE):
            print ("Type your phone number if you actually mean to join us!")
            text = input('\n>>> ')
            if re.search ("\d+|\+", text, flags=re.IGNORECASE):
                print ("Great! We will call you very soon. Bye Bye!")
                while True:
                    text = input('\n>>> ')
                    if re.search ("bye", text, flags=re.IGNORECASE):
                        break
                    
        elif re.search ("skip", text, flags=re.IGNORECASE):
            print ("ARE YOU SURE? But this is a great chance to save some money and make some new friends!")
            print ("Type your phone number if you actually mean to join us!")
            print ("Type bye if you are sure to leave :(")
            text = input('\n>>> ')
            if re.search ("\d+|\+", text, flags=re.IGNORECASE):
                print ("Great! We will call you very soon. Bye Bye!")
                while True:
                    text = input('\n>>> ')
                    if re.search ("bye", text, flags=re.IGNORECASE):
                        break
                
       
    if re.search ("bye", text, flags=re.IGNORECASE):
        break
        
    else:
        print ("I don't know what you are talking about...We should start from the begining!")
        print ("Which types of skin care products are you interested in?")
        print ("a. mask")
        print ("b. moisturizers")
        print ("c. serums")
        print ("d. cleansers")
        print ("e. eye cares")
        print ()
        print ("Or would you like to know more about our company?")
        print ("Type 'About us' to get more information!")
        
    
print ("Have a nice day!")
# Out:
# Hello! My name is Vivi. I am from JY-II skin care company, a lot of people ask for my reccomendation of skin care. What's your name?
